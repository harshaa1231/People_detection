# %%
import cv2
import csv
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO('yolov8n.pt')

# Function to detect people and count them
def detect_and_count_people(frame):
    results = model.predict(frame)  # Run detection on the current frame
    person_count = 0  # Initialize count

    # Draw bounding boxes and count people
    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get box coordinates
        label = results[0].names[int(box.cls)]  # Get the label of the detected object

        if label == 'person':  # Check if the detected object is a person
            person_count += 1  # Increment the person count
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw a green box around the person

    # Add people count text to the frame
    cv2.putText(frame, f"People Count: {person_count}", (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    return frame, person_count  # Return both the frame and the count

# Function to process video input, detect people, and save the results as a video
def process_and_save_video(input_path, output_video):
    cap = cv2.VideoCapture(input_path)  # Open the input video
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Frames per second of the original video

    # Initialize the VideoWriter object to save the output video
    out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

    frame_number = 0  # Initialize frame number

    # Process frames until the video ends or the user quits
    while cap.isOpened():
        ret, frame = cap.read()  # Read a frame
        if not ret:
            break  # Exit if no frame is read
        
        # Detect people in the frame
        output_frame, people_count = detect_and_count_people(frame)

        # Write the processed frame (with bounding boxes and people count) to the output video
        out.write(output_frame)

        # Display the processed frame in a window (optional)
        cv2.imshow('People Counting', output_frame)

        # Press 'q' to quit early
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        frame_number += 1

    # Release the video capture, writer object, and close display window
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
# Main function to run the program
if __name__ == "__main__":
    input_path = input("Enter the path to a video: ")  # e.g., '/path/to/video.mp4'
    output_video = input("Enter the path to save the processed video: ")  # e.g., '/path/to/output_video.mp4'
    process_and_save_video(input_path, output_video)  # Process video and save output
# Out:
# Enter the path to a video: /Users/harshavardhan/Downloads/Count.mp4
# Enter the path to save the processed video: /Users/harshavardhan/Downloads/video.mp4
#
# 0: 384x640 7 persons, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 36.9ms
# Speed: 1.2ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 backpack, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.0ms
# Speed: 1.2ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 30.9ms
# Speed: 1.1ms preprocess, 30.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.5ms
# Speed: 1.2ms preprocess, 24.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 handbag, 26.9ms
# Speed: 1.4ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 23.1ms
# Speed: 1.3ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 handbag, 26.4ms
# Speed: 1.0ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.3ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.5ms
# Speed: 1.2ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 backpack, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 32.6ms
# Speed: 1.1ms preprocess, 32.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 handbag, 27.3ms
# Speed: 1.3ms preprocess, 27.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 backpack, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 31.4ms
# Speed: 1.5ms preprocess, 31.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 28.7ms
# Speed: 1.0ms preprocess, 28.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.3ms
# Speed: 1.4ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.2ms
# Speed: 0.9ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 26.1ms
# Speed: 1.0ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.6ms
# Speed: 0.9ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.5ms
# Speed: 1.1ms preprocess, 22.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.0ms
# Speed: 1.2ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.1ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 backpack, 24.1ms
# Speed: 1.2ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.2ms
# Speed: 1.1ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.7ms
# Speed: 1.2ms preprocess, 24.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.5ms
# Speed: 1.3ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.8ms
# Speed: 1.2ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.1ms
# Speed: 1.2ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 9 persons, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 dog, 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.2ms
# Speed: 1.2ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.7ms
# Speed: 0.9ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.0ms
# Speed: 1.4ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.0ms
# Speed: 1.3ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.3ms
# Speed: 1.0ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.9ms
# Speed: 1.2ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.9ms
# Speed: 1.1ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.0ms
# Speed: 1.2ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.4ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.7ms
# Speed: 1.2ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.0ms
# Speed: 1.2ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.4ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.9ms
# Speed: 1.4ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 28.3ms
# Speed: 1.2ms preprocess, 28.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 22.8ms
# Speed: 1.0ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.1ms
# Speed: 1.1ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 10 persons, 22.9ms
# Speed: 1.1ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.7ms
# Speed: 1.2ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.4ms
# Speed: 1.2ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.1ms
# Speed: 1.1ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 21.8ms
# Speed: 1.2ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.2ms
# Speed: 1.2ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.7ms
# Speed: 1.2ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 21.8ms
# Speed: 1.0ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.5ms
# Speed: 1.3ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.9ms
# Speed: 1.1ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.3ms
# Speed: 1.2ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.4ms
# Speed: 1.2ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 21.8ms
# Speed: 1.1ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 26.0ms
# Speed: 0.9ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.5ms
# Speed: 1.2ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 fire hydrant, 22.6ms
# Speed: 1.2ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 23.9ms
# Speed: 1.2ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 fire hydrant, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.4ms
# Speed: 1.1ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 27.3ms
# Speed: 1.1ms preprocess, 27.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.0ms
# Speed: 1.2ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.6ms
# Speed: 1.2ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.7ms
# Speed: 1.1ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26.3ms
# Speed: 1.4ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.6ms
# Speed: 1.2ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.5ms
# Speed: 1.1ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.5ms
# Speed: 1.4ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.2ms
# Speed: 1.2ms preprocess, 25.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.5ms
# Speed: 1.1ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.8ms
# Speed: 0.9ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.9ms
# Speed: 1.2ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.2ms
# Speed: 0.9ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.8ms
# Speed: 1.2ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 21.8ms
# Speed: 1.2ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.1ms
# Speed: 1.2ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.4ms
# Speed: 0.9ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.5ms
# Speed: 1.3ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.4ms
# Speed: 0.9ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.2ms
# Speed: 0.9ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.3ms
# Speed: 1.1ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 persons, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.7ms
# Speed: 1.1ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.8ms
# Speed: 1.2ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.6ms
# Speed: 1.3ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.7ms
# Speed: 1.4ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 26.8ms
# Speed: 1.2ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 24.0ms
# Speed: 1.2ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.0ms
# Speed: 0.9ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.8ms
# Speed: 1.3ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 21.4ms
# Speed: 1.2ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 27.6ms
# Speed: 0.9ms preprocess, 27.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.8ms
# Speed: 1.2ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.7ms
# Speed: 0.9ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.3ms
# Speed: 1.2ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.5ms
# Speed: 0.9ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.8ms
# Speed: 0.9ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.2ms
# Speed: 1.2ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.4ms
# Speed: 1.1ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 23.1ms
# Speed: 1.2ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.6ms
# Speed: 1.3ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 persons, 28.5ms
# Speed: 1.2ms preprocess, 28.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 28.1ms
# Speed: 1.2ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.7ms
# Speed: 1.1ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 27.0ms
# Speed: 1.2ms preprocess, 27.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 22.6ms
# Speed: 1.1ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.0ms
# Speed: 1.2ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.6ms
# Speed: 1.3ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 23.7ms
# Speed: 1.1ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
